# %% [markdown]
# # Scheduled Integration of ClinVar Gene Variant-Disease Data into WikiData
#
# ClinVar aggregates information about genomic variation and its relationship to human health <br>
# CC0 https://www.ncbi.nlm.nih.gov/clinvar/
#
# This scheduled bot operates through WDI to integrate ClinVar Gene Variant-Disease Data <br>
# https://github.com/SuLab/GeneWikiCentral/issues/50 <br>
#
# Python script contributions, in order: Sabah Ul-Hasan, Andrew I Su

# %%
# Download data from NCBI

# Make sure os has wget installed, or the command wont work
import os
os.system('wget ftp://ftp.ncbi.nlm.nih.gov/pub/clinvar/tab_delimited/variant_summary.txt.gz') 

# Create time stamp of when downloaded (error if isoformat() used)
from datetime import datetime
timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z")

# Unzip the file
import gzip
import shutil
with gzip.open('variant_summary.txt.gz', 'rb') as f_in:
    with open('variant_summary.txt', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)
        
# Convert .txt file to .csv
import pandas as pd 
import csv

txt_file = r"variant_summary.txt"
csv_file = r"variant_summary.csv"

with open(txt_file, "r") as in_text:
    in_reader = csv.reader(in_text, delimiter = '\t')
    with open(csv_file, "w") as out_csv:
        out_writer = csv.writer(out_csv)
        for row in in_reader:
            out_writer.writerow(row)

# Import .csv file and read first 5 rows
data = pd.read_csv("variant_summary.csv") 
data.shape # 31 columns, 1319815 rows
data.head()
# Out:
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    #AlleleID                       Type  \
# 0     191195                duplication
# 1     191196  single nucleotide variant
# 2     191196  single nucleotide variant
# 3     191197  single nucleotide variant
# 4     191197  single nucleotide variant
#
#                                           Name  GeneID GeneSymbol     HGNC_ID  \
# 0              NM_006920.6(SCN1A):c.2011-13dup    6323      SCN1A  HGNC:10585
# 1             NM_001182.5(ALDH7A1):c.1093+1G>A     501    ALDH7A1    HGNC:877
# 2             NM_001182.5(ALDH7A1):c.1093+1G>A     501    ALDH7A1    HGNC:877
# 3  NM_001195263.2(PDZD7):c.1752T>C (p.Tyr584=)   79955      PDZD7  HGNC:26257
# 4  NM_001195263.2(PDZD7):c.1752T>C (p.Tyr584=)   79955      PDZD7  HGNC:26257
#
#                            ClinicalSignificance  ClinSigSimple LastEvaluated  \
# 0  Conflicting interpretations of pathogenicity              0  Feb 15, 2019
# 1                                    Pathogenic              1  Feb 23, 2015
# 2                                    Pathogenic              1  Feb 23, 2015
# 3                                 Likely benign              0  Mar 16, 2015
# 4                                 Likely benign              0  Mar 16, 2015
#
#    RS# (dbSNP)  ... ReferenceAllele AlternateAllele Cytogenetic  \
# 0    549232924  ...               T              TA      2q24.3
# 1    794727058  ...               C               T      5q23.2
# 2    794727058  ...               C               T      5q23.2
# 3    368563439  ...               A               G    10q24.31
# 4    368563439  ...               A               G    10q24.31
#
#                                      ReviewStatus NumberSubmitters Guidelines  \
# 0  criteria provided, conflicting interpretations                3        NaN
# 1             criteria provided, single submitter                1        NaN
# 2             criteria provided, single submitter                1        NaN
# 3             criteria provided, single submitter                1        NaN
# 4             criteria provided, single submitter                1        NaN
#
#   TestedInGTR OtherIDs SubmitterCategories  VariationID
# 0           N        -                   2       194032
# 1           N        -                   2       194033
# 2           N        -                   2       194033
# 3           N        -                   2       194034
# 4           N        -                   2       194034
#
# [5 rows x 31 columns]

# %%
# Clean-up the data for identification and integration

# Columns to keep
new = data[['Type', 'Name','GeneID','GeneSymbol','HGNC_ID', 'ClinicalSignificance','VariationID', 
            'ChromosomeAccession', 'Chromosome', 'Start', 'ReferenceAllele', 'AlternateAllele',
            'ReviewStatus']]
new.shape # 12 columns, 1319815 rows
new.head()
# Out:
#                         Type                                         Name  \
# 0                duplication              NM_006920.6(SCN1A):c.2011-13dup
# 1  single nucleotide variant             NM_001182.5(ALDH7A1):c.1093+1G>A
# 2  single nucleotide variant             NM_001182.5(ALDH7A1):c.1093+1G>A
# 3  single nucleotide variant  NM_001195263.2(PDZD7):c.1752T>C (p.Tyr584=)
# 4  single nucleotide variant  NM_001195263.2(PDZD7):c.1752T>C (p.Tyr584=)
#
#    GeneID GeneSymbol     HGNC_ID  \
# 0    6323      SCN1A  HGNC:10585
# 1     501    ALDH7A1    HGNC:877
# 2     501    ALDH7A1    HGNC:877
# 3   79955      PDZD7  HGNC:26257
# 4   79955      PDZD7  HGNC:26257
#
#                            ClinicalSignificance  VariationID  \
# 0  Conflicting interpretations of pathogenicity       194032
# 1                                    Pathogenic       194033
# 2                                    Pathogenic       194033
# 3                                 Likely benign       194034
# 4                                 Likely benign       194034
#
#   ChromosomeAccession Chromosome      Start ReferenceAllele AlternateAllele  \
# 0        NC_000002.12          2  166042429               T              TA
# 1         NC_000005.9          5  125891622               C               T
# 2        NC_000005.10          5  126555930               C               T
# 3        NC_000010.10         10  102772013               A               G
# 4        NC_000010.11         10  101012256               A               G
#
#                                      ReviewStatus
# 0  criteria provided, conflicting interpretations
# 1             criteria provided, single submitter
# 2             criteria provided, single submitter
# 3             criteria provided, single submitter
# 4             criteria provided, single submitter

# %%
# Create new column that converts 'ReviewStatus' to star rating
## https://www.ncbi.nlm.nih.gov/clinvar/docs/review_status/

new['Rating'] = "" # Create empty column for gold star rating

## Convert strings from 'ReviewStatus' to 'Rating' 
new.loc[new['ReviewStatus'].str.contains('no assertion provided'), 'Rating'] = 'none'
new.loc[new['ReviewStatus'].str.contains('no assertion criteria provided'), 'Rating'] = 'none'
new.loc[new['ReviewStatus'].str.contains('no assertion for the individual variant'), 'Rating'] = 'none'
new.loc[new['ReviewStatus'].str.contains('criteria provided, single submitter'), 'Rating'] = 'one'
new.loc[new['ReviewStatus'].str.contains('criteria provided, conflicting interpretations'), 'Rating'] = 'one'
new.loc[new['ReviewStatus'].str.contains('criteria provided, conflicting interpretations'), 'Rating'] = 'one'
new.loc[new['ReviewStatus'].str.contains('criteria provided, multiple submitters, no conflicts'), 'Rating'] = 'two'
new.loc[new['ReviewStatus'].str.contains('reviewed by expert panel'), 'Rating'] = 'three'
new.loc[new['ReviewStatus'].str.contains('practice guideline'), 'Rating'] = 'four'
# Out:
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Keep anything with 'three' or more stars in 'Rating' column
threeplus = new[new['Rating'].str.contains('three|four')] # excludes both one and none
threeplus.shape # 14 columns, 1299197 rows
# Keep anything noted as 'single nucleotide variant' in 'Type' column
snv = threeplus[threeplus['Type'].str.contains('single nucleotide variant')]
snv.shape # 1087133 rows
# Keep anything with 'Pathogenic' in the 'ClinicalSignificance' column
patho = snv[snv['ClinicalSignificance'].str.contains('Pathogenic')]
patho.shape # 3778 rows
# Out:
# (3778, 14)

# %%
# Create HGVS Column and IDs
patho['HGVS_NC'] = "" # Create empty column for HGVS nomenclature with NC
patho['HGVS_chr'] = "" # Create empty column for HGVS nomenclature with chr
# Naming nomenclature: https://varnomen.hgvs.org/bg-material/numbering/


# Filtering only for SNV addresses any instances of 'del'
# Insertion of GC for Wikidata... address this later
test = patho
test['HGVS_NC']=test['ChromosomeAccession']+':g.'+test['Start'].astype(str)+test['ReferenceAllele']+'>'+test['AlternateAllele']
test['HGVS_chr']='chr'+test['Chromosome'].astype(str)+':g.'+test['Start'].astype(str)+test['ReferenceAllele']+'>'+test['AlternateAllele']
test.head()

test.to_csv("test.csv")
# Out:
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#                             Type                                         Name  \
# 6692   single nucleotide variant               NM_206933.3(USH2A):c.8682-9A>G
# 6693   single nucleotide variant               NM_206933.3(USH2A):c.8682-9A>G
# 25569  single nucleotide variant                NM_000492.3(CFTR):c.1117-1G>A
# 25570  single nucleotide variant                NM_000492.3(CFTR):c.1117-1G>A
# 25577  single nucleotide variant                NM_000492.3(CFTR):c.2658-1G>C
# 25578  single nucleotide variant                NM_000492.3(CFTR):c.2658-1G>C
# 25579  single nucleotide variant   NM_000492.3(CFTR):c.3294G>A (p.Trp1098Ter)
# 25580  single nucleotide variant   NM_000492.3(CFTR):c.3294G>A (p.Trp1098Ter)
# 39533  single nucleotide variant  NM_000059.3(BRCA2):c.6022A>T (p.Lys2008Ter)
# 39534  single nucleotide variant  NM_000059.3(BRCA2):c.6022A>T (p.Lys2008Ter)
# 39559  single nucleotide variant  NM_000059.3(BRCA2):c.7872T>G (p.Tyr2624Ter)
# 39560  single nucleotide variant  NM_000059.3(BRCA2):c.7872T>G (p.Tyr2624Ter)
# 39570  single nucleotide variant  NM_000059.3(BRCA2):c.8143A>T (p.Lys2715Ter)
# 39571  single nucleotide variant  NM_000059.3(BRCA2):c.8143A>T (p.Lys2715Ter)
# 39576  single nucleotide variant  NM_000059.3(BRCA2):c.8420C>A (p.Ser2807Ter)
# 39577  single nucleotide variant  NM_000059.3(BRCA2):c.8420C>A (p.Ser2807Ter)
# 40023  single nucleotide variant  NM_007294.3(BRCA1):c.4474G>T (p.Gly1492Ter)
# 40024  single nucleotide variant  NM_007294.3(BRCA1):c.4474G>T (p.Gly1492Ter)
# 44581  single nucleotide variant   NM_000179.2(MSH6):c.3632T>C (p.Leu1211Pro)
# 44582  single nucleotide variant   NM_000179.2(MSH6):c.3632T>C (p.Leu1211Pro)
# 44587  single nucleotide variant    NM_000249.3(MLH1):c.2263A>G (p.Arg755Gly)
# 44588  single nucleotide variant    NM_000249.3(MLH1):c.2263A>G (p.Arg755Gly)
# 47204  single nucleotide variant  NM_000059.3(BRCA2):c.3191C>G (p.Ser1064Ter)
# 47205  single nucleotide variant  NM_000059.3(BRCA2):c.3191C>G (p.Ser1064Ter)
# 47240  single nucleotide variant  NM_000059.3(BRCA2):c.5016C>G (p.Tyr1672Ter)
# 47241  single nucleotide variant  NM_000059.3(BRCA2):c.5016C>G (p.Tyr1672Ter)
# 47262  single nucleotide variant  NM_000059.3(BRCA2):c.6254T>G (p.Leu2085Ter)
# 47263  single nucleotide variant  NM_000059.3(BRCA2):c.6254T>G (p.Leu2085Ter)
# 47298  single nucleotide variant  NM_000059.3(BRCA2):c.8987T>A (p.Leu2996Ter)
# 47299  single nucleotide variant  NM_000059.3(BRCA2):c.8987T>A (p.Leu2996Ter)
# ...                          ...                                          ...
# 52088  single nucleotide variant     NM_000277.3(PAH):c.1243G>A (p.Asp415Asn)
# 52089  single nucleotide variant     NM_000277.3(PAH):c.1243G>A (p.Asp415Asn)
# 52090  single nucleotide variant      NM_000277.3(PAH):c.916A>G (p.Ile306Val)
# 52091  single nucleotide variant      NM_000277.3(PAH):c.916A>G (p.Ile306Val)
# 52092  single nucleotide variant     NM_000277.3(PAH):c.1162G>A (p.Val388Met)
# 52093  single nucleotide variant     NM_000277.3(PAH):c.1162G>A (p.Val388Met)
# 52104  single nucleotide variant     NM_000277.3(PAH):c.1169A>G (p.Glu390Gly)
# 52105  single nucleotide variant     NM_000277.3(PAH):c.1169A>G (p.Glu390Gly)
# 52110  single nucleotide variant     NM_000277.3(PAH):c.1139C>T (p.Thr380Met)
# 52111  single nucleotide variant     NM_000277.3(PAH):c.1139C>T (p.Thr380Met)
# 52118  single nucleotide variant      NM_000277.3(PAH):c.734T>C (p.Val245Ala)
# 52119  single nucleotide variant      NM_000277.3(PAH):c.734T>C (p.Val245Ala)
# 52126  single nucleotide variant       NM_000277.3(PAH):c.194T>C (p.Ile65Thr)
# 52127  single nucleotide variant       NM_000277.3(PAH):c.194T>C (p.Ile65Thr)
# 54183  single nucleotide variant    NM_000251.2(MSH2):c.1865C>T (p.Pro622Leu)
# 54184  single nucleotide variant    NM_000251.2(MSH2):c.1865C>T (p.Pro622Leu)
# 54186  single nucleotide variant    NM_000251.2(MSH2):c.1216C>T (p.Arg406Ter)
# 54187  single nucleotide variant    NM_000251.2(MSH2):c.1216C>T (p.Arg406Ter)
# 54188  single nucleotide variant    NM_000251.2(MSH2):c.1915C>T (p.His639Tyr)
# 54189  single nucleotide variant    NM_000251.2(MSH2):c.1915C>T (p.His639Tyr)
# 54192  single nucleotide variant    NM_000251.2(MSH2):c.1801C>T (p.Gln601Ter)
# 54193  single nucleotide variant    NM_000251.2(MSH2):c.1801C>T (p.Gln601Ter)
# 54202  single nucleotide variant    NM_000251.2(MSH2):c.1906G>C (p.Ala636Pro)
# 54203  single nucleotide variant    NM_000251.2(MSH2):c.1906G>C (p.Ala636Pro)
# 59828  single nucleotide variant  NM_000441.2(SLC26A4):c.412G>T (p.Val138Phe)
# 59829  single nucleotide variant  NM_000441.2(SLC26A4):c.412G>T (p.Val138Phe)
# 59837  single nucleotide variant              NM_000441.2(SLC26A4):c.919-2A>G
# 59838  single nucleotide variant              NM_000441.2(SLC26A4):c.919-2A>G
# 62384  single nucleotide variant    NM_004700.4(KCNQ4):c.853G>A (p.Gly285Ser)
# 62385  single nucleotide variant    NM_004700.4(KCNQ4):c.853G>A (p.Gly285Ser)
#
#        GeneID GeneSymbol     HGNC_ID ClinicalSignificance  VariationID  \
# 6692     7399      USH2A  HGNC:12601           Pathogenic       197510
# 6693     7399      USH2A  HGNC:12601           Pathogenic       197510
# 25569    1080       CFTR   HGNC:1884           Pathogenic       209059
# 25570    1080       CFTR   HGNC:1884           Pathogenic       209059
# 25577    1080       CFTR   HGNC:1884           Pathogenic       209045
# 25578    1080       CFTR   HGNC:1884           Pathogenic       209045
# 25579    1080       CFTR   HGNC:1884           Pathogenic       209057
# 25580    1080       CFTR   HGNC:1884           Pathogenic       209057
# 39533     675      BRCA2   HGNC:1101           Pathogenic       216029
# 39534     675      BRCA2   HGNC:1101           Pathogenic       216029
# 39559     675      BRCA2   HGNC:1101           Pathogenic       216031
# 39560     675      BRCA2   HGNC:1101           Pathogenic       216031
# 39570     675      BRCA2   HGNC:1101           Pathogenic       216032
# 39571     675      BRCA2   HGNC:1101           Pathogenic       216032
# 39576     675      BRCA2   HGNC:1101           Pathogenic       216033
# 39577     675      BRCA2   HGNC:1101           Pathogenic       216033
# 40023     672      BRCA1   HGNC:1100           Pathogenic       216105
# 40024     672      BRCA1   HGNC:1100           Pathogenic       216105
# 44581    2956       MSH6   HGNC:7329           Pathogenic       219294
# 44582    2956       MSH6   HGNC:7329           Pathogenic       219294
# 44587    4292       MLH1   HGNC:7127           Pathogenic       219292
# 44588    4292       MLH1   HGNC:7127           Pathogenic       219292
# 47204     675      BRCA2   HGNC:1101           Pathogenic       220624
# 47205     675      BRCA2   HGNC:1101           Pathogenic       220624
# 47240     675      BRCA2   HGNC:1101           Pathogenic       219406
# 47241     675      BRCA2   HGNC:1101           Pathogenic       219406
# 47262     675      BRCA2   HGNC:1101           Pathogenic       219426
# 47263     675      BRCA2   HGNC:1101           Pathogenic       219426
# 47298     675      BRCA2   HGNC:1101           Pathogenic       219665
# 47299     675      BRCA2   HGNC:1101           Pathogenic       219665
# ...       ...        ...         ...                  ...          ...
# 52088    5053        PAH   HGNC:8582           Pathogenic          617
# 52089    5053        PAH   HGNC:8582           Pathogenic          617
# 52090    5053        PAH   HGNC:8582           Pathogenic          618
# 52091    5053        PAH   HGNC:8582           Pathogenic          618
# 52092    5053        PAH   HGNC:8582           Pathogenic          619
# 52093    5053        PAH   HGNC:8582           Pathogenic          619
# 52104    5053        PAH   HGNC:8582           Pathogenic          625
# 52105    5053        PAH   HGNC:8582           Pathogenic          625
# 52110    5053        PAH   HGNC:8582           Pathogenic          628
# 52111    5053        PAH   HGNC:8582           Pathogenic          628
# 52118    5053        PAH   HGNC:8582           Pathogenic          632
# 52119    5053        PAH   HGNC:8582           Pathogenic          632
# 52126    5053        PAH   HGNC:8582           Pathogenic          636
# 52127    5053        PAH   HGNC:8582           Pathogenic          636
# 54183    4436       MSH2   HGNC:7325           Pathogenic         1753
# 54184    4436       MSH2   HGNC:7325           Pathogenic         1753
# 54186    4436       MSH2   HGNC:7325           Pathogenic         1755
# 54187    4436       MSH2   HGNC:7325           Pathogenic         1755
# 54188    4436       MSH2   HGNC:7325           Pathogenic         1756
# 54189    4436       MSH2   HGNC:7325           Pathogenic         1756
# 54192    4436       MSH2   HGNC:7325           Pathogenic         1758
# 54193    4436       MSH2   HGNC:7325           Pathogenic         1758
# 54202    4436       MSH2   HGNC:7325           Pathogenic         1764
# 54203    4436       MSH2   HGNC:7325           Pathogenic         1764
# 59828    5172    SLC26A4   HGNC:8818           Pathogenic         4835
# 59829    5172    SLC26A4   HGNC:8818           Pathogenic         4835
# 59837    5172    SLC26A4   HGNC:8818           Pathogenic         4840
# 59838    5172    SLC26A4   HGNC:8818           Pathogenic         4840
# 62384    9132      KCNQ4   HGNC:6298           Pathogenic         6241
# 62385    9132      KCNQ4   HGNC:6298           Pathogenic         6241
#
#       ChromosomeAccession Chromosome      Start ReferenceAllele  \
# 6692         NC_000001.10          1  216040521               T
# 6693         NC_000001.11          1  215867179               T
# 25569        NC_000007.13          7  117182069               G
# 25570        NC_000007.14          7  117542015               G
# 25577        NC_000007.13          7  117243585               G
# 25578        NC_000007.14          7  117603531               G
# 25579        NC_000007.13          7  117251789               G
# 25580        NC_000007.14          7  117611735               G
# 39533        NC_000013.11         13   32340377               A
# 39534        NC_000013.10         13   32914514               A
# 39559        NC_000013.10         13   32936726               T
# 39560        NC_000013.11         13   32362589               T
# 39570        NC_000013.10         13   32937482               A
# 39571        NC_000013.11         13   32363345               A
# 39576        NC_000013.11         13   32370490               C
# 39577        NC_000013.10         13   32944627               C
# 40023        NC_000017.11         17   43076498               C
# 40024        NC_000017.10         17   41228515               C
# 44581        NC_000002.12          2   47805693               T
# 44582        NC_000002.11          2   48032832               T
# 44587        NC_000003.11          3   37092136               A
# 44588        NC_000003.12          3   37050645               A
# 47204        NC_000013.10         13   32911683               C
# 47205        NC_000013.11         13   32337546               C
# 47240        NC_000013.10         13   32913508               C
# 47241        NC_000013.11         13   32339371               C
# 47262        NC_000013.10         13   32914746               T
# 47263        NC_000013.11         13   32340609               T
# 47298        NC_000013.10         13   32953920               T
# 47299        NC_000013.11         13   32379783               T
# 47240   NC_000013.10:g.32913508C>G
# 47241   NC_000013.11:g.32339371C>G
# 47262   NC_000013.10:g.32914746T>G
# 47263   NC_000013.11:g.32340609T>G
# 47298   NC_000013.10:g.32953920T>A
# 47299   NC_000013.11:g.32379783T>A
# ...                            ...
# 52088  NC_000012.11:g.103234250C>T
# 52089  NC_000012.12:g.102840472C>T
# 52090  NC_000012.11:g.103240726T>C
# 52091  NC_000012.12:g.102846948T>C
# 52092  NC_000012.11:g.103237461C>T
# 52093  NC_000012.12:g.102843683C>T
# 52104  NC_000012.11:g.103237454T>C
# 52105  NC_000012.12:g.102843676T>C
# 52110  NC_000012.11:g.103237484G>A
# 52111  NC_000012.12:g.102843706G>A
# 52118  NC_000012.11:g.103246701A>G
# 52119  NC_000012.12:g.102852923A>G
# 52126  NC_000012.11:g.103288671A>G
# 52127  NC_000012.12:g.102894893A>G
# 54183   NC_000002.11:g.47702269C>T
# 54184   NC_000002.12:g.47475130C>T
# 54186   NC_000002.11:g.47657020C>T
# 54187   NC_000002.12:g.47429881C>T
# 54188   NC_000002.11:g.47702319C>T
# 54189   NC_000002.12:g.47475180C>T
# 54192   NC_000002.11:g.47702205C>T
# 54193   NC_000002.12:g.47475066C>T
# 54202   NC_000002.11:g.47702310G>C
# 54203   NC_000002.12:g.47475171G>C
# 59828  NC_000007.13:g.107312690G>T
# 59829  NC_000007.14:g.107672245G>T
# 59837  NC_000007.13:g.107323898A>G
# 59838  NC_000007.14:g.107683453A>G
# 62384   NC_000001.10:g.41285565G>A
# 62385   NC_000001.11:g.40819893G>A
#
# [100 rows x 17 columns]

# %%
query = pd.read_csv("/Users/sulhasan/Desktop/Su Lab Projects/ClinVar-Bot_GeneWikiCentral-Issue50/query.csv")  
query = query[query['HGVS'].str.contains('chr|NC_',  na=False)] # subset for NC or chr
query.head()
# Out:
#                                          gene  \
# 0    http://www.wikidata.org/entity/Q28599633
# 1    http://www.wikidata.org/entity/Q28599639
# 2    http://www.wikidata.org/entity/Q28599624
# 3    http://www.wikidata.org/entity/Q28599634
# 11   http://www.wikidata.org/entity/Q29938348
# 12   http://www.wikidata.org/entity/Q29938352
# 13   http://www.wikidata.org/entity/Q29938697
# 14   http://www.wikidata.org/entity/Q29938644
# 15   http://www.wikidata.org/entity/Q29938740
# 16   http://www.wikidata.org/entity/Q29938724
# 17   http://www.wikidata.org/entity/Q29938565
# 18   http://www.wikidata.org/entity/Q29938572
# 19   http://www.wikidata.org/entity/Q29938574
# 20   http://www.wikidata.org/entity/Q29938587
# 21   http://www.wikidata.org/entity/Q29938331
# 22   http://www.wikidata.org/entity/Q29938423
# 23   http://www.wikidata.org/entity/Q29938429
# 24   http://www.wikidata.org/entity/Q29938489
# 25   http://www.wikidata.org/entity/Q29938655
# 26   http://www.wikidata.org/entity/Q29938527
# 36   http://www.wikidata.org/entity/Q29938470
# 37   http://www.wikidata.org/entity/Q29938472
# 38   http://www.wikidata.org/entity/Q28371428
# 39   http://www.wikidata.org/entity/Q29938774
# 40   http://www.wikidata.org/entity/Q29938520
# 41   http://www.wikidata.org/entity/Q29938717
# 42   http://www.wikidata.org/entity/Q29938523
# 43   http://www.wikidata.org/entity/Q29938312
# 44   http://www.wikidata.org/entity/Q29938042
# 61   http://www.wikidata.org/entity/Q32965526
# ..                                        ...
# 147  http://www.wikidata.org/entity/Q28371271
# 148  http://www.wikidata.org/entity/Q28371422
# 149  http://www.wikidata.org/entity/Q28371643
# 150  http://www.wikidata.org/entity/Q28371363
# 151  http://www.wikidata.org/entity/Q28371040
# 152  http://www.wikidata.org/entity/Q28371219
# 153  http://www.wikidata.org/entity/Q28371664
# 184  http://www.wikidata.org/entity/Q28423335
# 185  http://www.wikidata.org/entity/Q28439513
# 189  http://www.wikidata.org/entity/Q28531493
# 192  http://www.wikidata.org/entity/Q28599657
# 198  http://www.wikidata.org/entity/Q28599652
# 199  http://www.wikidata.org/entity/Q28599668
# 204  http://www.wikidata.org/entity/Q64401263
# 205  http://www.wikidata.org/entity/Q64401263
# 206  http://www.wikidata.org/entity/Q64401263
# 219  http://www.wikidata.org/entity/Q27908461
# 220  http://www.wikidata.org/entity/Q27906612
# 225  http://www.wikidata.org/entity/Q28045565
# 226  http://www.wikidata.org/entity/Q28045562
# 252  http://www.wikidata.org/entity/Q28371498
# 253  http://www.wikidata.org/entity/Q28371650
# 254  http://www.wikidata.org/entity/Q28371651
# 255  http://www.wikidata.org/entity/Q28371582
# 256  http://www.wikidata.org/entity/Q28371034
# 257  http://www.wikidata.org/entity/Q28371028
# 258  http://www.wikidata.org/entity/Q28381464
# 259  http://www.wikidata.org/entity/Q28371432
# 260  http://www.wikidata.org/entity/Q28370986
# 261  http://www.wikidata.org/entity/Q28371540
#
#                                             HGVS
# 0                     NC_000003.11:g.37038139T>C
# 1                     NC_000003.11:g.37081770A>C
# 2            NC_000003.11:g.37089094_37089095del
# 3                     NC_000003.11:g.37090406del
# 11                           chr1:g.115258745C>A
# 12                           chr1:g.115258748C>T
# 13                          chr11:g.108186827C>T
# 14                           chr12:g.25380277G>C
# 15                           chr13:g.32900751G>C
# 16                           chr17:g.41276111C>A
# 17                            chr17:g.7577556C>A
# 18                            chr17:g.7577574T>C
# 19                            chr17:g.7577580T>C
# 20                            chr17:g.7578257C>A
# 21                           chr3:g.178936092A>C
# 22                   chr4:g.55593597_55593602del
# 23                            chr4:g.55593603T>G
# 24                 chr7:g.55593669_55593671insGC
# 25                           chr9:g.139399344A>T
# 26                           chr9:g.139399350C>G
# 36                    NC_000004.11:g.55599332G>T
# 37                    NC_000004.11:g.55599341T>G
# 38                   NC_000006.11:g.117638347C>T
# 39                   NC_000006.11:g.117638347C>T
# 40                   NC_000009.11:g.133748391T>C
# 41                   NC_000009.11:g.133750330G>C
# 42                   NC_000009.11:g.133750356A>G
# 43                    NC_000017.10:g.37881378A>G
# 44            NC_000021.8:g.36252913_36252920del
# 61                            chr2:g.29443642C>G
# ..                                           ...
# 147                   NC_000007.13:g.55241722G>A
# 148                   NC_000007.13:g.55242487C>T
# 149                   NC_000007.13:g.55242500A>G
# 150                    NC_000016.9:g.69745145G>A
# 151                    NC_000017.10:g.7577539G>A
# 152                    NC_000019.9:g.45854919T>G
# 153                   NC_000022.10:g.29121087A>G
# 184                  NC_000002.11:g.202149589G>C
# 185                    NC_000014.8:g.62213848T>C
# 189                      NC_000011.9:g.534285C>T
# 192                            chr7:g.6031649G>A
# 198                  NC_000002.11:g.47630414dupG
# 199                   NC_000003.11:g.10188302G>T
# 204                  NC_000012.10:g.101835038T>C
# 205                  NC_000012.11:g.103310908T>C
# 206                  NC_000012.12:g.102917130T>C
# 219   NC_000007.13:g.140477859_140477860delinsCA
# 220                  NC_000009.11:g.133748283C>T
# 225                   NC_000002.11:g.29443631G>T
# 226                  NC_000007.13:g.140453145A>C
# 252                   NC_000001.10:g.11184573G>T
# 253                   NC_000001.10:g.97915614C>T
# 254                   NC_000001.10:g.97981343A>C
# 255                   NC_000003.11:g.10191605C>T
# 256                  NC_000003.11:g.178952085A>G
# 257  NC_000004.11:g.55152093_55152097delinsTCATG
# 258          NC_000004.11:g.55152095_55152097del
# 259                   NC_000004.11:g.55968180T>A
# 260   NC_000006.11:g.152419920_152419921delinsAG
# 261                  NC_000007.13:g.140453134T>C
#
# [100 rows x 2 columns]

# %%
mergedStuff = pd.merge(test, query, on=['HGVS'], how='inner')
mergedStuff.shape 

# 365 of all ClinVar (no filter) match NC_ HGVS of 574 possible in Wikidata
## 80 with two or more stars, SNV, and Pathogenic
### 13 three or more stars (0 with 4)
# 130 of all ClinVar (no filter) match chr HGVS of 244 possible in Wikidata
## 24 with two or more stars, SNV, and Pathogenic
### 0 with three or more stars
# Out:
# (13, 17)

# %%
# Keep anything with 'two' or more stars in 'Rating' column
twoplus = new[~new['Rating'].str.contains('one')] # excludes both one and none
twoplus.shape # 13 columns, 196530 rows: 1123285 removed, 14.9 % of all data usable
# Keep anything noted as 'single nucleotide variant' in 'Type' column
snv = twoplus[twoplus['Type'].str.contains('single nucleotide variant')]
snv.shape # 174733 rows, or 88.9% of data with two or more stars (13.2% of all data)
## 83.2 % of total data, prior to star rating filter, are SNVs
# Keep anything with 'Pathogenic' in the 'ClinicalSignificance' column
patho = snv[snv['ClinicalSignificance'].str.contains('Pathogenic')]
patho.shape # 20040 rows, or 10.2% of data with two or more stars that are snvs (1.5% of all data)
## 12.8 % of total data, prior to star rating filter, are Pathogenic

# %%
# Keep anything with 'four' or more stars in 'Rating' column
four = new[new['Rating'].str.contains('four')] # excludes both one and none
four.shape # 13 columns, 63 rows
# Keep anything noted as 'single nucleotide variant' in 'Type' column
snv = four[four['Type'].str.contains('single nucleotide variant')]
snv.shape # 54 rows
# Keep anything with 'Pathogenic' in the 'ClinicalSignificance' column
patho = snv[snv['ClinicalSignificance'].str.contains('Pathogenic')]
patho.shape # 38 rows
