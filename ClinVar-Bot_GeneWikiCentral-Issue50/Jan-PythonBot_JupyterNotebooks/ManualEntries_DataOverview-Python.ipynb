# %%
import os
import pandas as pd 

# os.getcwd()

data = pd.read_csv("variant_summary.csv") 
data.head()
# Out:
#    #AlleleID                       Type  \
# 0      15041                      indel
# 1      15041                      indel
# 2      15042                   deletion
# 3      15042                   deletion
# 4      15043  single nucleotide variant
#
#                                                 Name  GeneID GeneSymbol  \
# 0  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 1  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 2     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 3     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 4       NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)    9640     ZNF592
#
#       HGNC_ID    ClinicalSignificance  ClinSigSimple LastEvaluated  \
# 0  HGNC:22197              Pathogenic              1     29-Jun-10
# 1  HGNC:22197              Pathogenic              1     29-Jun-10
# 2  HGNC:22197              Pathogenic              1     29-Jun-10
# ...

# %%
data['ClinicalSignificance'].value_counts()
# Out:
# Pathogenic                                                  13818
# no interpretation for the single variant                     1195
# risk factor                                                   316
# Uncertain significance                                        190
# Conflicting interpretations of pathogenicity                  174
# Pathogenic/Likely pathogenic                                  112
# Benign                                                         98
# association                                                    77
# Pathogenic, other                                              72
# Affects                                                        56
# other                                                          46
# Pathogenic, risk factor                                        45
# drug response                                                  42
# protective                                                     22
# ...
