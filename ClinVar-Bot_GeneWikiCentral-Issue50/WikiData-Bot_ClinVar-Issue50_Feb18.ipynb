# %% [markdown]
# # Scheduled Integration of ClinVar Gene Variant-Disease Data into WikiData
#
# ClinVar aggregates information about genomic variation and its relationship to human health <br>
# CC0 https://www.ncbi.nlm.nih.gov/clinvar/
#
# This scheduled bot operates monthly through WDI to integrate ClinVar Gene Variant-Disease Data <br>
# https://www.ncbi.nlm.nih.gov/clinvar/docs/ftp_primer/ (variant_summary) <br>
# https://github.com/SuLab/GeneWikiCentral/issues/50 <br>
# http://jenkins.sulab.org/ <br>
#
# Python script contributions, in order: Sabah Ul-Hasan, Andrew I Su, Tong Shu Li

# %%
# Relevant Modules and Libraries

import os # OS package to ensure interaction between the modules (ie WDI) and current OS being used

from datetime import datetime # For identifying the current date and time
import time # Keep track of total for loop run time

import gzip # For unzip of files
import shutil # Copies content of source file(s)
import csv # For converting file(s) to csv format

import pandas as pd # For data organization, abbreviated to pd
import numpy as np # For data organization, abbreviated as np

from wikidataintegrator import wdi_core, wdi_login # Core and login from wikidataintegrator module
from wikidataintegrator.ref_handlers import update_retrieved_if_new_multiple_refs # For retrieving references
from wikidataintegrator.wdi_helpers import try_write # For writing new item pages

# %%
# Download data from NCBI

## Make sure os has wget installed, or the following command wont work
os.system('wget ftp://ftp.ncbi.nlm.nih.gov/pub/clinvar/tab_delimited/variant_summary.txt.gz') 
timeStringNow = datetime.now().strftime("+%Y-%m-%dT00:00:00Z") # time stamp of download 

## Unzip the file
with gzip.open('variant_summary.txt.gz', 'rb') as f_in:
    with open('variant_summary.txt', 'wb') as f_out:
        shutil.copyfileobj(f_in, f_out)
        
## Convert .txt file to .csv
txt_file = r"variant_summary.txt"
csv_file = r"variant_summary.csv"

with open(txt_file, "r") as in_text:
    in_reader = csv.reader(in_text, delimiter = '\t')
    with open(csv_file, "w") as out_csv:
        out_writer = csv.writer(out_csv)
        for row in in_reader:
            out_writer.writerow(row)

# %%
## Import .csv file and read first 5 rows
df = pd.read_csv("variant_summary.csv") 
df.shape # 31 columns, 1339084 rows
df.head()
# Out:
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (1339084, 31)

# %%
# Clean-up of data for identification and integration

## Columns to keep
new = df[['Type', 'Name', 'GeneSymbol','HGNC_ID', 'ClinicalSignificance', 'PhenotypeIDS', 'PhenotypeList','VariationID', 
            'ChromosomeAccession', 'Chromosome', 'Start', 'ReferenceAllele', 'AlternateAllele',
            'ReviewStatus']]

## Create new column that converts 'ReviewStatus' to star rating
### https://www.ncbi.nlm.nih.gov/clinvar/docs/review_status/
new['Rating'] = "" # Create empty column for gold star rating
## Convert strings from 'ReviewStatus' to 'Rating' 
new.loc[new['ReviewStatus'].str.contains('no assertion provided'), 'Rating'] = 'none'
new.loc[new['ReviewStatus'].str.contains('no assertion criteria provided'), 'Rating'] = 'none'
new.loc[new['ReviewStatus'].str.contains('no assertion for the individual variant'), 'Rating'] = 'none'
new.loc[new['ReviewStatus'].str.contains('criteria provided, single submitter'), 'Rating'] = 'one'
new.loc[new['ReviewStatus'].str.contains('criteria provided, conflicting interpretations'), 'Rating'] = 'one'
new.loc[new['ReviewStatus'].str.contains('criteria provided, conflicting interpretations'), 'Rating'] = 'one'
new.loc[new['ReviewStatus'].str.contains('criteria provided, multiple submitters, no conflicts'), 'Rating'] = 'two'
new.loc[new['ReviewStatus'].str.contains('reviewed by expert panel'), 'Rating'] = 'three'
new.loc[new['ReviewStatus'].str.contains('practice guideline'), 'Rating'] = 'four'

new.shape # 15 columns, 1339084 rows 

## Training dataset, based on the following criteria
threeplus=new[new['Rating'].str.contains('three|four')]
snv=threeplus[threeplus['Type'].str.contains('single nucleotide variant')]
patho=snv[snv['ClinicalSignificance'].str.contains('Pathogenic')]

patho.shape # 15 columns, 3870 rows (0.29% of original dataset)

## Create HGVS columns and IDs (based on genomic position)
### Naming nomenclature: https://varnomen.hgvs.org/bg-material/numbering/
patho['HGVS_NC'] = "" # Create empty column for HGVS nomenclature with NC
patho['HGVS_chr'] = "" # Create empty column for HGVS nomenclature with chr

patho['HGVS_NC']=patho['ChromosomeAccession']+':g.'+patho['Start'].astype(str)+patho['ReferenceAllele']+'>'+patho['AlternateAllele']
patho['HGVS_chr']='chr'+patho['Chromosome'].astype(str)+':g.'+patho['Start'].astype(str)+patho['ReferenceAllele']+'>'+patho['AlternateAllele']

df=patho
df.head()
# Out:
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/sulhasan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                             Type                                         Name  \
# 23254  single nucleotide variant  NM_000059.3(BRCA2):c.8490G>A (p.Trp2830Ter)
# 23255  single nucleotide variant  NM_000059.3(BRCA2):c.8490G>A (p.Trp2830Ter)
# 24036  single nucleotide variant  NM_000059.3(BRCA2):c.6044T>A (p.Leu2015Ter)
# 24037  single nucleotide variant  NM_000059.3(BRCA2):c.6044T>A (p.Leu2015Ter)
# 24358  single nucleotide variant    NM_004360.5(CDH1):c.1023T>G (p.Tyr341Ter)
#
#       GeneSymbol    HGNC_ID ClinicalSignificance  \
# 23254      BRCA2  HGNC:1101           Pathogenic
# 23255      BRCA2  HGNC:1101           Pathogenic
# 24036      BRCA2  HGNC:1101           Pathogenic
# 24037      BRCA2  HGNC:1101           Pathogenic
# 24358       CDH1  HGNC:1748           Pathogenic
#
#                                             PhenotypeIDS  \
# 23254  MedGen:C2675520,OMIM:612555;MedGen:C0006142,OM...
# 23255  MedGen:C2675520,OMIM:612555;MedGen:C0006142,OM...
# 24036  MedGen:C2675520,OMIM:612555;MedGen:C0027672,SN...
# 24037  MedGen:C2675520,OMIM:612555;MedGen:C0027672,SN...
# 24358    MedGen:C1708349,OMIM:137215,Orphanet:ORPHA26106
#
#                                            PhenotypeList  VariationID  \
# 23254  Breast-ovarian cancer, familial 2;Familial can...       155722
# 23255  Breast-ovarian cancer, familial 2;Familial can...       155722
# 24036  Breast-ovarian cancer, familial 2;Hereditary c...       156172
# 24037  Breast-ovarian cancer, familial 2;Hereditary c...       156172
# 24358                  Hereditary diffuse gastric cancer       156374
#
#       ChromosomeAccession Chromosome     Start ReferenceAllele  \
# 23254        NC_000013.10         13  32945095               G
# 23255        NC_000013.11         13  32370958               G
# 24036        NC_000013.11         13  32340399               T
# 24037        NC_000013.10         13  32914536               T
# 24358        NC_000016.10         16  68812149               T
#
#       AlternateAllele              ReviewStatus Rating  \
# 23254               A  reviewed by expert panel  three
# 23255               A  reviewed by expert panel  three
# 24036               A  reviewed by expert panel  three
# 24037               A  reviewed by expert panel  three
# 24358               G  reviewed by expert panel  three
#
#                           HGVS_NC             HGVS_chr
# 23254  NC_000013.10:g.32945095G>A  chr13:g.32945095G>A
# 23255  NC_000013.11:g.32370958G>A  chr13:g.32370958G>A
# 24036  NC_000013.11:g.32340399T>A  chr13:g.32340399T>A
# 24037  NC_000013.10:g.32914536T>A  chr13:g.32914536T>A
# 24358  NC_000016.10:g.68812149T>G  chr16:g.68812149T>G

# %%
# Login for running WDI
print("Logging in...") 

# **remove lines when scheduling to Jenkins** Enter your own username and password 
os.environ["WDUSER"] = "username" # Uses os package to call and set the environment for wikidata username
os.environ["WDPASS"] = "password"

## Conditional that outputs error command if not in the local python environment
if "WDUSER" in os.environ and "WDPASS" in os.environ: 
    WDUSER = os.environ['WDUSER']
    WDPASS = os.environ['WDPASS']
else: 
    raise ValueError("WDUSER and WDPASS must be specified in local.py or as environment variables")      

## Sets attributed username and password as 'login'
login = wdi_login.WDLogin(WDUSER, WDPASS)
# Out:
# Logging in...
# https://www.wikidata.org/w/api.php
# Successfully logged in as Sulhasan

# %%
df = df[(df['HGVS_NC'].str.contains("NC_000012.11:g.103234177C>T|NC_000002.11:g.47656951C>T|NC_000003.11:g.37038192G>A|NC_000003.11:g.37042536C>T|NC_000003.11:g.37045935C>T|NC_000003.11:g.37048546C>T|NC_000003.11:g.37053589C>T|NC_000003.11:g.37056036G>A|NC_000017.10:g.7577539G>A|NC_000017.10:g.7577548C>T|NC_000017.10:g.7578190T>C|NC_000021.8:g.36171704G>T|NC_000021.8:g.36252962C>G|NC_000021.8:g.36259163T>C|NC_000010.10:g.89711899C>T|NC_000012.11:g.103310908T>C|NC_000012.12:g.102917130T>C|NC_000017.10:g.7577120C>T|NC_000017.10:g.7577538C>T"))|(df['HGVS_chr'].str.contains("chr17:g.41228590G>A|chr17:g.41234451G>A"))]
df.shape # 21 x 17

# First 1 NC does not match to Wikidata, chr (2) do not match to Wikidata *18 possible writes of 21
df.head(21)
# Out:
#                              Type  \
# 63376   single nucleotide variant
# 141117  single nucleotide variant
# 141137  single nucleotide variant
# 141138  single nucleotide variant
# 162457  single nucleotide variant
# 162484  single nucleotide variant
# 162512  single nucleotide variant
# 162517  single nucleotide variant
# 166485  single nucleotide variant
# 166489  single nucleotide variant
# 166491  single nucleotide variant
# 171084  single nucleotide variant
# 171094  single nucleotide variant
# 172160  single nucleotide variant
# 183641  single nucleotide variant
# 215595  single nucleotide variant
# 241556  single nucleotide variant
# 241933  single nucleotide variant
# 242160  single nucleotide variant
# 242498  single nucleotide variant
# 268756  single nucleotide variant
#
#                                                Name GeneSymbol     HGNC_ID  \
# 63376      NM_000314.7(PTEN):c.517C>T (p.Arg173Cys)       PTEN   HGNC:9588
# 141117                 NM_000277.3(PAH):c.1315+1G>A        PAH   HGNC:8582
# 141137          NM_000277.3(PAH):c.1A>G (p.Met1Val)        PAH   HGNC:8582
# 141138          NM_000277.3(PAH):c.1A>G (p.Met1Val)        PAH   HGNC:8582
# 162457     NM_000546.5(TP53):c.742C>T (p.Arg248Trp)       TP53  HGNC:11998
# 162484     NM_000546.5(TP53):c.743G>A (p.Arg248Gln)       TP53  HGNC:11998
# 162512     NM_000546.5(TP53):c.733G>A (p.Gly245Ser)       TP53  HGNC:11998
# 162517     NM_000546.5(TP53):c.818G>A (p.Arg273His)       TP53  HGNC:11998
# 166485    NM_001754.4(RUNX1):c.328A>G (p.Lys110Glu)      RUNX1  HGNC:10471
# 166489    NM_001754.4(RUNX1):c.861C>A (p.Tyr287Ter)      RUNX1  HGNC:10471
# 166491    NM_001754.4(RUNX1):c.400G>C (p.Ala134Pro)      RUNX1  HGNC:10471
# 171084     NM_000249.3(MLH1):c.676C>T (p.Arg226Ter)       MLH1   HGNC:7127
# 171094     NM_000249.3(MLH1):c.350C>T (p.Thr117Met)       MLH1   HGNC:7127
# 172160   NM_007299.4(BRCA1):c.1018C>T (p.Arg340Ter)      BRCA1   HGNC:1100
# 183641     NM_000249.3(MLH1):c.298C>T (p.Arg100Ter)       MLH1   HGNC:7127
# 215595  NM_007294.3(BRCA1):c.4399C>T (p.Gln1467Ter)      BRCA1   HGNC:1100
# 241556      NM_000249.3(MLH1):c.199G>A (p.Gly67Arg)       MLH1   HGNC:7127
# 241933     NM_000249.3(MLH1):c.445C>T (p.Gln149Ter)       MLH1   HGNC:7127
# 242160                 NM_000249.3(MLH1):c.790+1G>A       MLH1   HGNC:7127
# 242498    NM_000251.2(MSH2):c.1147C>T (p.Arg383Ter)       MSH2   HGNC:7325
# 268756     NM_000546.5(TP53):c.659A>G (p.Tyr220Cys)       TP53  HGNC:11998
#
#        ClinicalSignificance  \
# 63376            Pathogenic
# 141117           Pathogenic
# 141137           Pathogenic
# 141138           Pathogenic
# 162457           Pathogenic
# 162484           Pathogenic
# 162512           Pathogenic
# 162517           Pathogenic
# 166485           Pathogenic
# 166489           Pathogenic
# 166491           Pathogenic
# 171084           Pathogenic
# 171094           Pathogenic
# 172160           Pathogenic
# 183641           Pathogenic
# 215595           Pathogenic
# 241556           Pathogenic
# 241933           Pathogenic
# 242160           Pathogenic
# 242498           Pathogenic
# 268756           Pathogenic
#
#                                              PhenotypeIDS  \
# 63376   MedGen:CN072330,OMIM:158350;MedGen:CN072330,OM...
# 141117  MeSH:D030342,MedGen:C0950123;MedGen:C0751434,O...
# 141137  Human Phenotype Ontology:HP:0004923,MedGen:C07...
# 141138  Human Phenotype Ontology:HP:0004923,MedGen:C07...
# 162457  Human Phenotype Ontology:HP:0000157,MedGen:C08...
# 162484  Human Phenotype Ontology:HP:0004808,MeSH:D0154...
# 162512  MedGen:C0001418;MedGen:C0007112;MedGen:C027870...
# 162517  Human Phenotype Ontology:HP:0004808,MeSH:D0154...
# 166485  MedGen:C1832388,OMIM:601399,Orphanet:ORPHA7129...
# 166489    MedGen:C1832388,OMIM:601399,Orphanet:ORPHA71290
# 166491    MedGen:C1832388,OMIM:601399,Orphanet:ORPHA71290
# 171084  MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
# 171094  MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
# 172160  MedGen:CN221562;MedGen:C2676676,OMIM:604370;Me...
# 183641  MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
# 215595  MedGen:CN221562;MedGen:C2676676,OMIM:604370;Me...
# 241556  MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
# 241933  MedGen:C1333990,Orphanet:ORPHA144,SNOMED CT:31...
# 242160  MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
# 242498  MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
# 268756  Human Phenotype Ontology:HP:0004808,MeSH:D0154...
#
#                                             PhenotypeList  VariationID  \
# 63376   Cowden syndrome 1;Cowden syndrome 1;Glioma sus...       189500
# 141117  Inborn genetic diseases;Phenylketonuria;not pr...          576
# 141137  Hyperphenylalaninemia, non-pku;Phenylketonuria...          586
# 141138  Hyperphenylalaninemia, non-pku;Phenylketonuria...          586
# 162457  Abnormality of the tongue;Acute myeloid leukem...        12347
# 162484  Acute myeloid leukemia;Adenocarcinoma of prost...        12356
# 162512  Adenocarcinoma;Adenocarcinoma of prostate;Aden...        12365
# 162517  Acute myeloid leukemia;Adenocarcinoma of prost...        12366
# 166485  Familial platelet disorder with associated mye...        14465
# 166489  Familial platelet disorder with associated mye...        14467
# 166491  Familial platelet disorder with associated mye...        14468
# 171084  Hereditary cancer-predisposing syndrome;Heredi...        17087
# 171094  Hereditary cancer-predisposing syndrome;Heredi...        17094
# 172160  Breast and/or ovarian cancer;Breast-ovarian ca...        17675
# 183641  Hereditary cancer-predisposing syndrome;Heredi...        36550
# 215595  Breast and/or ovarian cancer;Breast-ovarian ca...        55191
# 241556  Hereditary cancer-predisposing syndrome;Heredi...        89992
# 241933                                     Lynch syndrome        90219
# 242160  Hereditary cancer-predisposing syndrome;Heredi...        90356
# 242498  Hereditary cancer-predisposing syndrome;Heredi...        90554
# 268756  Acute myeloid leukemia;Adenocarcinoma of prost...       127819
#
#        ChromosomeAccession Chromosome      Start ReferenceAllele  \
# 63376         NC_000010.10         10   89711899               C
# 141117        NC_000012.11         12  103234177               C
# 141137        NC_000012.11         12  103310908               T
# 141138        NC_000012.12         12  102917130               T
# 162457        NC_000017.10         17    7577539               G
# 162484        NC_000017.10         17    7577538               C
# 162512        NC_000017.10         17    7577548               C
# 162517        NC_000017.10         17    7577120               C
# 166485         NC_000021.8         21   36259163               T
# 166489         NC_000021.8         21   36171704               G
# 166491         NC_000021.8         21   36252962               C
# 171084        NC_000003.11          3   37053589               C
# 171094        NC_000003.11          3   37045935               C
# 172160        NC_000017.10         17   41234451               G
# 183641        NC_000003.11          3   37042536               C
# 215595        NC_000017.10         17   41228590               G
# 241556        NC_000003.11          3   37038192               G
# 241933        NC_000003.11          3   37048546               C
# 242160        NC_000003.11          3   37056036               G
# 242498        NC_000002.11          2   47656951               C
# 268756        NC_000017.10         17    7578190               T
#
#        AlternateAllele              ReviewStatus Rating  \
# 63376                T  reviewed by expert panel  three
# 141117               T  reviewed by expert panel  three
# 141137               C  reviewed by expert panel  three
# 141138               C  reviewed by expert panel  three
# 162457               A  reviewed by expert panel  three
# 162484               T  reviewed by expert panel  three
# 162512               T  reviewed by expert panel  three
# 162517               T  reviewed by expert panel  three
# 166485               C  reviewed by expert panel  three
# 166489               T  reviewed by expert panel  three
# 166491               G  reviewed by expert panel  three
# 171084               T  reviewed by expert panel  three
# 171094               T  reviewed by expert panel  three
# 172160               A  reviewed by expert panel  three
# 183641               T  reviewed by expert panel  three
# 215595               A  reviewed by expert panel  three
# 241556               A  reviewed by expert panel  three
# 241933               T  reviewed by expert panel  three
# 242160               A  reviewed by expert panel  three
# 242498               T  reviewed by expert panel  three
# 268756               C  reviewed by expert panel  three
#
#                             HGVS_NC              HGVS_chr
# 63376    NC_000010.10:g.89711899C>T   chr10:g.89711899C>T
# 141117  NC_000012.11:g.103234177C>T  chr12:g.103234177C>T
# 141137  NC_000012.11:g.103310908T>C  chr12:g.103310908T>C
# 141138  NC_000012.12:g.102917130T>C  chr12:g.102917130T>C
# 162457    NC_000017.10:g.7577539G>A    chr17:g.7577539G>A
# 162484    NC_000017.10:g.7577538C>T    chr17:g.7577538C>T
# 162512    NC_000017.10:g.7577548C>T    chr17:g.7577548C>T
# 162517    NC_000017.10:g.7577120C>T    chr17:g.7577120C>T
# 166485    NC_000021.8:g.36259163T>C   chr21:g.36259163T>C
# 166489    NC_000021.8:g.36171704G>T   chr21:g.36171704G>T
# 166491    NC_000021.8:g.36252962C>G   chr21:g.36252962C>G
# 171084   NC_000003.11:g.37053589C>T    chr3:g.37053589C>T
# 171094   NC_000003.11:g.37045935C>T    chr3:g.37045935C>T
# 172160   NC_000017.10:g.41234451G>A   chr17:g.41234451G>A
# 183641   NC_000003.11:g.37042536C>T    chr3:g.37042536C>T
# 215595   NC_000017.10:g.41228590G>A   chr17:g.41228590G>A
# 241556   NC_000003.11:g.37038192G>A    chr3:g.37038192G>A
# 241933   NC_000003.11:g.37048546C>T    chr3:g.37048546C>T
# 242160   NC_000003.11:g.37056036G>A    chr3:g.37056036G>A
# 242498   NC_000002.11:g.47656951C>T    chr2:g.47656951C>T
# 268756    NC_000017.10:g.7578190T>C    chr17:g.7578190T>C

# %%
# Training data, Feb 18

# No match (need item page)
## NC_000012.11:g.103234177C>T

# Single NC match
## NC_000010.10:g.89711899C>T

# Single chr match
## chr17:g.41234451G>A

# Two NC matches in for same Wikidata item page, but different entries
## NC_000012.11:g.103310908T>C
## NC_000012.12:g.102917130T>C

# NC matches to two different Wikidata item pages (remove from Sandbox https://www.wikidata.org/wiki/Q4115189)
## NC_000002.11:g.47656951C>T

# One NC match, one chr match manually entered (Feb 11)
## NC_000017.10:g.7577539G>A
## chr17:g.7577539G>A


df = df[(df['HGVS_NC'].str.contains("NC_000012.11:g.103234177C>T|NC_000010.10:g.89711899C>T|NC_000012.11:g.103310908T>C|NC_000012.12:g.102917130T>C|NC_000002.11:g.47656951C>T|NC_000017.10:g.7577539G>A"))|(df['HGVS_chr'].str.contains("chr17:g.41234451G>A|chr17:g.7577539G>A"))]
df.shape # 7 x 17
df.head(7)
# Out:
#                              Type                                        Name  \
# 63376   single nucleotide variant    NM_000314.7(PTEN):c.517C>T (p.Arg173Cys)
# 141117  single nucleotide variant                NM_000277.3(PAH):c.1315+1G>A
# 141137  single nucleotide variant         NM_000277.3(PAH):c.1A>G (p.Met1Val)
# 141138  single nucleotide variant         NM_000277.3(PAH):c.1A>G (p.Met1Val)
# 162457  single nucleotide variant    NM_000546.5(TP53):c.742C>T (p.Arg248Trp)
# 172160  single nucleotide variant  NM_007299.4(BRCA1):c.1018C>T (p.Arg340Ter)
# 242498  single nucleotide variant   NM_000251.2(MSH2):c.1147C>T (p.Arg383Ter)
#
#        GeneSymbol     HGNC_ID ClinicalSignificance  \
# 63376        PTEN   HGNC:9588           Pathogenic
# 141117        PAH   HGNC:8582           Pathogenic
# 141137        PAH   HGNC:8582           Pathogenic
# 141138        PAH   HGNC:8582           Pathogenic
# 162457       TP53  HGNC:11998           Pathogenic
# 172160      BRCA1   HGNC:1100           Pathogenic
# 242498       MSH2   HGNC:7325           Pathogenic
#
#                                              PhenotypeIDS  \
# 63376   MedGen:CN072330,OMIM:158350;MedGen:CN072330,OM...
# 141117  MeSH:D030342,MedGen:C0950123;MedGen:C0751434,O...
# 141137  Human Phenotype Ontology:HP:0004923,MedGen:C07...
# 141138  Human Phenotype Ontology:HP:0004923,MedGen:C07...
# 162457  Human Phenotype Ontology:HP:0000157,MedGen:C08...
# 172160  MedGen:CN221562;MedGen:C2676676,OMIM:604370;Me...
# 242498  MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
#
#                                             PhenotypeList  VariationID  \
# 63376   Cowden syndrome 1;Cowden syndrome 1;Glioma sus...       189500
# 141117  Inborn genetic diseases;Phenylketonuria;not pr...          576
# 141137  Hyperphenylalaninemia, non-pku;Phenylketonuria...          586
# 141138  Hyperphenylalaninemia, non-pku;Phenylketonuria...          586
# 162457  Abnormality of the tongue;Acute myeloid leukem...        12347
# 172160  Breast and/or ovarian cancer;Breast-ovarian ca...        17675
# 242498  Hereditary cancer-predisposing syndrome;Heredi...        90554
#
#        ChromosomeAccession Chromosome      Start ReferenceAllele  \
# 63376         NC_000010.10         10   89711899               C
# 141117        NC_000012.11         12  103234177               C
# 141137        NC_000012.11         12  103310908               T
# 141138        NC_000012.12         12  102917130               T
# 162457        NC_000017.10         17    7577539               G
# 172160        NC_000017.10         17   41234451               G
# 242498        NC_000002.11          2   47656951               C
#
#        AlternateAllele              ReviewStatus Rating  \
# 63376                T  reviewed by expert panel  three
# 141117               T  reviewed by expert panel  three
# 141137               C  reviewed by expert panel  three
# 141138               C  reviewed by expert panel  three
# 162457               A  reviewed by expert panel  three
# 172160               A  reviewed by expert panel  three
# 242498               T  reviewed by expert panel  three
#
#                             HGVS_NC              HGVS_chr
# 63376    NC_000010.10:g.89711899C>T   chr10:g.89711899C>T
# 141117  NC_000012.11:g.103234177C>T  chr12:g.103234177C>T
# 141137  NC_000012.11:g.103310908T>C  chr12:g.103310908T>C
# 141138  NC_000012.12:g.102917130T>C  chr12:g.102917130T>C
# 162457    NC_000017.10:g.7577539G>A    chr17:g.7577539G>A
# 172160   NC_000017.10:g.41234451G>A   chr17:g.41234451G>A
# 242498   NC_000002.11:g.47656951C>T    chr2:g.47656951C>T

# %%
df['Variant Qid'] = "" # To be replaced with Qid, 'absent', or 'multiple' 
df['Disease Qid'] = ""

# %%
# Start time of for loop run 
start_time = time.time() 

# For loop on training dataset
for index, row in df.iterrows(): 
    
    # Assign string for a given row in the data table to retrieve the Wikidata Qid for item page 
    ## Criterion: HGVS identifier for genomic ids only (exclude cDNA *ENST and NM* and protein *NP*)
    HGVS_NC = row['HGVS_NC'] 
    HGVS_chr = row['HGVS_chr'] 
    
    # SparQL query to search HGVS Identifier (P3331) in Wikidata 
    sparqlQuery_HGVSNC = "SELECT * WHERE {?variant wdt:P3331 \""+HGVS_NC+"\"}" 
    result_HGVSNC = wdi_core.WDItemEngine.execute_sparql_query(sparqlQuery_HGVSNC) 
    sparqlQuery_HGVSchr = "SELECT * WHERE {?variant wdt:P3331 \""+HGVS_chr+"\"}" 
    result_HGVSchr = wdi_core.WDItemEngine.execute_sparql_query(sparqlQuery_HGVSchr)   
    
    # Assign variants of query results to respective lists 
    NC = result_HGVSNC["results"]["bindings"]
    CHR = result_HGVSchr["results"]["bindings"]
    
    # Concatenate to then distinguish 3 scenarios via for loop 
    HGVSarray = np.concatenate((NC,CHR), axis=0)
    
    HGVSlist = [] 
    
    for i in range(len(HGVSarray)):

        ### Output all unique lists within array (accounts for duplicates)
        if HGVSarray[i] not in HGVSarray[i + 1:]: 
            HGVSlist.append(HGVSarray[i])
            
    ## Scen 1: Flag if HGVS identifier(s) correspond to multiple Wikidata item pages
    if len(HGVSlist) > 1: 
        df.at[index, 'Variant Qid'] = "multiple"
        ### Why does row['Variant Qid'] = "multiple" call show as empty?
        print("Multiple Qids for (",HGVS_NC, ") and/or (", HGVS_chr,") :\n", HGVSlist)
        ### How to specify / list out all Qids for which one(s) are multiple?
        continue
            
    # Scen 2: Write item page if no identifiers available
    ## Andra
    if len(HGVSlist) == 0:
        df.at[index, 'Variant Qid'] = "absent"          
        #try_write(HGVS_NC, 
        #          edit_summary=("gene variant in human gene ", df.loc[index, 'GeneSymbol']),
        #          record_id = Qid,
        #          record_prop = 'human gene variant',
        #          login = login)
        #print("item page created")
        continue
        
    # Scenario 3: Go forward with write if only one item page between NC and chr     
    Variant_Qid = HGVSlist[0]["variant"]["value"].replace("http://www.wikidata.org/entity/", "")
    df.at[index, 'Variant Qid'] = Variant_Qid      
    # Add missing NC or chr (HGVS nomenclature: P3331)   
    # Add VariationID (ClinVar Variation ID: P3329)
    
    test = row['PhenotypeIDS'].replace(";", "\n")
    print(test)
    
    # Look at Disease
    ## Simultaneously split PhenotypeIDS and PhenotypeList into multiple rows by (;)
        # * such that you only have the list of ids for one corresponding disease assocation
        ### If any of the PhenotypeIDS between rows are identical to each other, then remove duplicate row(s)
        ### Then, sparql query the first PhenotypeIDS in that row by (:) and (,) to find the corresponding disease Qid
        #### If no Qid for that id, then keep going
        ##### If no Qid for all in that row (PhenotypeIDs), write 'absent' and create item page
        ##### If multiple Qids for that disease, flag and write 'multiple'
    #   ##### If only one Qid for that disease across all PhenotypeIDs, then write association for variant
    #   ###### Do symmetry write on disease page

end_time = time.time() # Captures when loop run ends
print("The total time of this loop is:", end_time - start_time, "seconds, or", (end_time - start_time)/60, "minutes")

df.head(7)
# Out:
# MedGen:CN072330,OMIM:158350
# MedGen:CN072330,OMIM:158350
# MedGen:C2751642,OMIM:613028
# MedGen:C0027672,SNOMED CT:699346009
# MedGen:C1854416,OMIM:605309,Orphanet:ORPHA210548
# MedGen:C1854416,OMIM:605309,Orphanet:ORPHA210548
# Human Phenotype Ontology:HP:0012125,MedGen:C0376358,OMIM:176807,SNOMED CT:399068003
# MedGen:C3551915,OMIM:607174,Orphanet:ORPHA263662
# Human Phenotype Ontology:HP:0030692,MeSH:D001932,MedGen:C0006118,SNOMED CT:126952004
# MedGen:C1959582,OMIM:601728,Orphanet:ORPHA306498
# MedGen:C1959582,OMIM:601728,Orphanet:ORPHA306498
# MedGen:C1848599,OMIM:276950,Orphanet:ORPHA3412
# MedGen:C1848599,OMIM:276950,Orphanet:ORPHA3412
# MedGen:CN517202
# MedGen:CN169374
# Human Phenotype Ontology:HP:0004923,MedGen:C0751435
# MedGen:C0751434,OMIM:261600,Orphanet:ORPHA716,SNOMED CT:154735006
# MedGen:CN517202
# Human Phenotype Ontology:HP:0004923,MedGen:C0751435
# MedGen:C0751434,OMIM:261600,Orphanet:ORPHA716,SNOMED CT:154735006
# MedGen:CN517202
# Human Phenotype Ontology:HP:0000157,MedGen:C0878638
# Human Phenotype Ontology:HP:0004808,MeSH:D015470,MedGen:C0023467,OMIM:601626,Orphanet:ORPHA519,SNOMED CT:17788007
# Human Phenotype Ontology:HP:0004808,MeSH:D015470,MedGen:C0023467,OMIM:601626,Orphanet:ORPHA519,SNOMED CT:17788007
# MedGen:C0007112
# MedGen:C0278701
# Human Phenotype Ontology:HP:0010796,MedGen:C0677865
# Human Phenotype Ontology:HP:0011459,MedGen:C0152018,Orphanet:ORPHA70482
# Human Phenotype Ontology:HP:0005550,MeSH:D015451,MedGen:C0023434,OMIM:151400,Orphanet:ORPHA67038,SNOMED CT:277473004,SNOMED CT:51092000
# Human Phenotype Ontology:HP:0100543,MedGen:C0338656
# MeSH:D005909,MedGen:C0017636,Orphanet:ORPHA360,SNOMED CT:63634009
# Human Phenotype Ontology:HP:0001402,MedGen:C2239176,OMIM:114550,Orphanet:ORPHA88673,SNOMED CT:187769009,SNOMED CT:25370001
# MedGen:C0027672,SNOMED CT:699346009
# MedGen:C0085390,Orphanet:ORPHA524,SNOMED CT:428850001
# Gene:553989,MedGen:C1835398,OMIM:151623
# Human Phenotype Ontology:HP:0030078,MeSH:C538231,MedGen:C0152013
# MeSH:C562393,MedGen:C0151779,SNOMED CT:93655004
# MedGen:C0153574,Orphanet:ORPHA213569
# Human Phenotype Ontology:HP:0002885,MeSH:D008527,MedGen:C0025149,OMIM:155255,Orphanet:ORPHA616
# Human Phenotype Ontology:HP:0006775,MeSH:D009101,MedGen:C0026764,OMIM:254500,Orphanet:ORPHA29073,SNOMED CT:109989006,SNOMED CT:55921005
# MeSH:D009190,MedGen:C3463824,OMIM:614286,Orphanet:ORPHA52688
# Human Phenotype Ontology:HP:0002664,MeSH:D009369,MedGen:C0027651,SNOMED CT:108369006
# Human Phenotype Ontology:HP:0030692,MeSH:D001932,MedGen:C0006118,SNOMED CT:126952004
# Human Phenotype Ontology:HP:0100013,MeSH:D001943,MedGen:C1458155,Orphanet:ORPHA180250,SNOMED CT:126926005
# Human Phenotype Ontology:HP:0100834,MeSH:D015179,MedGen:C0009404,SNOMED CT:126837005
# MeSH:D010051,MedGen:CN236629
# MedGen:C0279663
# Human Phenotype Ontology:HP:0006725,MedGen:C0281361
# Human Phenotype Ontology:HP:0001876,MedGen:C0030312
# Human Phenotype Ontology:HP:0000767,MedGen:C0016842,OMIM:169300
# Human Phenotype Ontology:HP:0004322,MedGen:C0349588
# Human Phenotype Ontology:HP:0030357,MeSH:D055752,MedGen:C0149925,OMIM:182280,Orphanet:ORPHA70573
# MeSH:C535575,MedGen:C1168401,OMIM:275355,Orphanet:ORPHA67037
# Human Phenotype Ontology:HP:0006739,MedGen:C0553723
# Human Phenotype Ontology:HP:0030359,MedGen:C0149782
# Human Phenotype Ontology:HP:0006740,MedGen:C0279680
# MedGen:C0280630,Orphanet:ORPHA213610
# Human Phenotype Ontology:HP:0000465,MedGen:C0221217
# MedGen:CN517202
# MedGen:CN221562
# MedGen:C2676676,OMIM:604370
# MedGen:C2676676,OMIM:604370
# MedGen:C2676676,OMIM:604370
# MedGen:C4554406,OMIM:617883
# MedGen:C0006142,OMIM:114480,Orphanet:ORPHA227535,SNOMED CT:254843006
# MedGen:C0006142,OMIM:114480,Orphanet:ORPHA227535,SNOMED CT:254843006
# MedGen:C0006142,OMIM:114480,Orphanet:ORPHA227535,SNOMED CT:254843006
# MeSH:D061325,MedGen:C0677776,Orphanet:ORPHA145
# MedGen:C0027672,SNOMED CT:699346009
# MedGen:C3280442,OMIM:614320
# MedGen:C3280442,OMIM:614320
# MedGen:CN517202
# MedGen:CN169374
# Multiple Qids for ( NC_000002.11:g.47656951C>T ) and/or ( chr2:g.47656951C>T ) :
#  [{'variant': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4115189'}}, {'variant': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q28599622'}}]
# The total time of this loop is: 5.180696964263916 seconds, or 0.0863449494043986 minutes
#                              Type                                        Name  \
# 63376   single nucleotide variant    NM_000314.7(PTEN):c.517C>T (p.Arg173Cys)
# 141117  single nucleotide variant                NM_000277.3(PAH):c.1315+1G>A
# 141137  single nucleotide variant         NM_000277.3(PAH):c.1A>G (p.Met1Val)
# 141138  single nucleotide variant         NM_000277.3(PAH):c.1A>G (p.Met1Val)
# 162457  single nucleotide variant    NM_000546.5(TP53):c.742C>T (p.Arg248Trp)
# 172160  single nucleotide variant  NM_007299.4(BRCA1):c.1018C>T (p.Arg340Ter)
# 242498  single nucleotide variant   NM_000251.2(MSH2):c.1147C>T (p.Arg383Ter)
#
#        GeneSymbol     HGNC_ID ClinicalSignificance  \
# 63376        PTEN   HGNC:9588           Pathogenic
# 141117        PAH   HGNC:8582           Pathogenic
# 141137        PAH   HGNC:8582           Pathogenic
# 141138        PAH   HGNC:8582           Pathogenic
# 162457       TP53  HGNC:11998           Pathogenic
# 172160      BRCA1   HGNC:1100           Pathogenic
# 242498       MSH2   HGNC:7325           Pathogenic
#
#                                              PhenotypeIDS  \
# 63376   MedGen:CN072330,OMIM:158350;MedGen:CN072330,OM...
# 141117  MeSH:D030342,MedGen:C0950123;MedGen:C0751434,O...
# 141137  Human Phenotype Ontology:HP:0004923,MedGen:C07...
# 141138  Human Phenotype Ontology:HP:0004923,MedGen:C07...
# 162457  Human Phenotype Ontology:HP:0000157,MedGen:C08...
# 172160  MedGen:CN221562;MedGen:C2676676,OMIM:604370;Me...
# 242498  MedGen:C0027672,SNOMED CT:699346009;MedGen:C00...
#
#                                             PhenotypeList  VariationID  \
# 63376   Cowden syndrome 1;Cowden syndrome 1;Glioma sus...       189500
# 141117  Inborn genetic diseases;Phenylketonuria;not pr...          576
# 141137  Hyperphenylalaninemia, non-pku;Phenylketonuria...          586
# 141138  Hyperphenylalaninemia, non-pku;Phenylketonuria...          586
# 162457  Abnormality of the tongue;Acute myeloid leukem...        12347
# 172160  Breast and/or ovarian cancer;Breast-ovarian ca...        17675
# 242498  Hereditary cancer-predisposing syndrome;Heredi...        90554
#
#        ChromosomeAccession Chromosome      Start ReferenceAllele  \
# 63376         NC_000010.10         10   89711899               C
# 141117        NC_000012.11         12  103234177               C
# 141137        NC_000012.11         12  103310908               T
# 141138        NC_000012.12         12  102917130               T
# 162457        NC_000017.10         17    7577539               G
# 172160        NC_000017.10         17   41234451               G
# 242498        NC_000002.11          2   47656951               C
#
#        AlternateAllele              ReviewStatus Rating  \
# 63376                T  reviewed by expert panel  three
# 141117               T  reviewed by expert panel  three
# 141137               C  reviewed by expert panel  three
# 141138               C  reviewed by expert panel  three
# 162457               A  reviewed by expert panel  three
# 172160               A  reviewed by expert panel  three
# 242498               T  reviewed by expert panel  three
#
#                             HGVS_NC              HGVS_chr Variant Qid  \
# 63376    NC_000010.10:g.89711899C>T   chr10:g.89711899C>T   Q29938054
# 141117  NC_000012.11:g.103234177C>T  chr12:g.103234177C>T      absent
# 141137  NC_000012.11:g.103310908T>C  chr12:g.103310908T>C   Q64401263
# 141138  NC_000012.12:g.102917130T>C  chr12:g.102917130T>C   Q64401263
# 162457    NC_000017.10:g.7577539G>A    chr17:g.7577539G>A   Q28371040
# 172160   NC_000017.10:g.41234451G>A   chr17:g.41234451G>A   Q29938735
# 242498   NC_000002.11:g.47656951C>T    chr2:g.47656951C>T    multiple
#
#        Disease Qid
# 63376
# 141117
# 141137
# 141138
# 162457
# 172160
# 242498

# %%
## Download HGVS Wikidata query results as query.csv 
### https://query.wikidata.org/#SELECT%20%2a%20WHERE%20%7B%3Fgene%20wdt%3AP3331%20%3FHGVS%7D

query = pd.read_csv("/Users/sulhasan/Desktop/Su Lab Projects/ClinVar-Bot_GeneWikiCentral-Issue50/query.csv")  

## Subset for NC or chr
query = query[query['HGVS'].str.contains('chr|NC_',  na=False)] # 818 with NC or chr
query.head(5) 

# How many HGVS IDs match for Wikidata query (818) vs. manually created in ClinVar (3778 x 2 for NC or chr)
len(set(query["HGVS"]) & (set(df["HGVS_chr"]) | set(df["HGVS_NC"]))) # 17
set(query["HGVS"]) & (set(df["HGVS_chr"]) | set(hasHGVS["HGVS_NC"])) # 4 chr, 13 NC *chr dont match...
# Out:
# {'NC_000002.11:g.47656951C>T',
#  'NC_000003.11:g.37038192G>A',
#  'NC_000003.11:g.37042536C>T',
#  'NC_000003.11:g.37045935C>T',
#  'NC_000003.11:g.37048546C>T',
#  'NC_000003.11:g.37053589C>T',
#  'NC_000003.11:g.37056036G>A',
#  'NC_000010.10:g.89711899C>T',
#  'NC_000012.11:g.103310908T>C',
#  'NC_000012.12:g.102917130T>C',
#  'NC_000017.10:g.7577120C>T',
#  'NC_000017.10:g.7577538C>T',
#  'NC_000017.10:g.7577539G>A',
#  'NC_000017.10:g.7577548C>T',
#  'NC_000017.10:g.7578190T>C',
#  'NC_000021.8:g.36171704G>T',
#  'NC_000021.8:g.36252962C>G',
#  'NC_000021.8:g.36259163T>C'}

# %%
# Keep anything with 'two' or more stars in 'Rating' column
twoplus = new[~new['Rating'].str.contains('one')] # excludes both one and none
twoplus.shape # 13 columns, 196530 rows: 1123285 removed, 14.9 % of all data usable
# Keep anything noted as 'single nucleotide variant' in 'Type' column
snv = twoplus[twoplus['Type'].str.contains('single nucleotide variant')]
snv.shape # 174733 rows, or 88.9% of data with two or more stars (13.2% of all data)
## 83.2 % of total data, prior to star rating filter, are SNVs
# Keep anything with 'Pathogenic' in the 'ClinicalSignificance' column
patho = snv[snv['ClinicalSignificance'].str.contains('Pathogenic')]
patho.shape # 20040 rows, or 10.2% of data with two or more stars that are snvs (1.5% of all data)
## 12.8 % of total data, prior to star rating filter, are Pathogenic
