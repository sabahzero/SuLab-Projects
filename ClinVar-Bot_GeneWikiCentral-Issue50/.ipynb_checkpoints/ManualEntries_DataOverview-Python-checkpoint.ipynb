# %%
import os
import pandas as pd 

os.getcwd()

data = pd.read_csv("variant_summary.csv") 
data.head()
# Out:
#    #AlleleID                       Type  \
# 0      22145               short repeat
# 1      22145               short repeat
# 2      22149  single nucleotide variant
# 3      22149  single nucleotide variant
# 4      22150  single nucleotide variant
#
#                                         Name  GeneID GeneSymbol    HGNC_ID  \
# 0        NM_000492.3(CFTR):c.1519_1521delATC    1080       CFTR  HGNC:1884
# 1        NM_000492.3(CFTR):c.1519_1521delATC    1080       CFTR  HGNC:1884
# 2  NM_000492.3(CFTR):c.1040G>C (p.Arg347Pro)    1080       CFTR  HGNC:1884
# 3  NM_000492.3(CFTR):c.1040G>C (p.Arg347Pro)    1080       CFTR  HGNC:1884
# 4  NM_000492.3(CFTR):c.1364C>A (p.Ala455Glu)    1080       CFTR  HGNC:1884
#
#   ClinicalSignificance  ClinSigSimple LastEvaluated  RS# (dbSNP)  ...  \
# 0           Pathogenic              1      5-Nov-18    121908745  ...
# 1           Pathogenic              1      5-Nov-18    121908745  ...
# ...

# %%
data['ClinicalSignificance'].value_counts()
# Out:
# Pathogenic                                                  13818
# no interpretation for the single variant                     1195
# risk factor                                                   316
# Uncertain significance                                        190
# Conflicting interpretations of pathogenicity                  174
# Pathogenic/Likely pathogenic                                  112
# Benign                                                         98
# association                                                    77
# Pathogenic, other                                              72
# Affects                                                        56
# other                                                          46
# Pathogenic, risk factor                                        45
# drug response                                                  42
# protective                                                     22
# ...
